# %%
from src.models.components.matching import Embeddings

import os

# %%
em = Embeddings()

# %%
em.load_from_h5py(os.path.join(os.getcwd(), 'logs', 'embeddings.h5'))

# %%
em.train_feat.shape
# Out:
# (500, 512)

# %%
from src.models.components.matching import codec_train, retrieve_candidate_set

# %%
em=codec_train(embeddings=em, score_norm_arg = False)
# Out:
# Indexing codec
# Finish indexing codec
# Projecting codec
# Finish codec projection

# %%
retrieve_candidate_set(embeddings=em,k_candidates=10)
# Out:
# [(0, 0, -0.884313),
#  (0, 34, -0.9007255),
#  (0, 2, -1.0004082),
#  (0, 22, -1.0021379),
#  (0, 1, -1.0095844),
#  (0, 3, -1.0308902),
#  (0, 33, -1.0740596),
#  (0, 32, -1.0792854),
#  (0, 37, -1.0839264),
#  (0, 35, -1.0884962),
#  (1, 3, -0.3473673),
#  (1, 1, -0.3655058),
#  (1, 33, -0.3995607),
#  (1, 35, -0.40363288),
#  (1, 34, -0.55650926),
#  (1, 152, -0.56577754),
#  (1, 21, -0.574111),
#  (1, 2, -0.5772325),
#  (1, 20, -0.5866393),
#  (1, 18, -0.5942234),
#  (2, 34, -0.7633909),
#  (2, 152, -0.85686016),
#  (2, 35, -0.8677492),
#  (2, 33, -0.8758991),
#  (2, 32, -0.8841393),
#  (2, 1, -0.8847157),
#  (2, 3, -0.8882669),
#  (2, 112, -0.9172181),
#  (2, 20, -0.9225378),
#  (2, 153, -0.92766225),
#  (3, 3, -0.26775575),
#  (3, 35, -0.43416584),
#  (3, 1, -0.45524204),
#  (3, 33, -0.49842238),
#  (3, 152, -0.5563381),
#  (3, 2, -0.59167194),
#  (3, 21, -0.620507),
#  (3, 18, -0.6364864),
#  (3, 20, -0.6414399),
#  (3, 34, -0.6498983),
#  (4, 34, -0.89896643),
# ...
